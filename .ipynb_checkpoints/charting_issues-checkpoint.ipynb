# %% [markdown]
# # Plot the Graph for the total number of issues with different labels created and closed on every date on GitHub for SPM587SP19 issues project

# %% [markdown]
# ### Example of Issue Form Filled out

# %% [raw]
# Author: PSCM587SP19
# created_at: 2019-03-25,
# labels: bug,
# State: closed,
# issue_number: 1,
# closed_at: 2018-03-29

# %% [markdown]
# ### Data Set File:  SPM587SP19issues.json

# %%
import os
#import cPickle as pickle

import pandas as pd                                    # panda's nickname is pd

import numpy as np                                     # numpy as np

from pandas import DataFrame, Series                   # for convenience

import matplotlib.pyplot as plt


# %matplotlib inline

# %% [markdown]
# # Requirement : Get the total number of issues with different labels for every date and plot them in a stacked chart

# %%
# Read the JSON file into a list of dictionaries

import json
list_of_issues_dict_data = [json.loads(line) for line in open('SPM587SP19issues.json')]

# %%
# Create the DataFrame object for the list_of_issues_dict_data object

issues_df = DataFrame(list_of_issues_dict_data)

# %%
# Sanity test: print first 10 rows in our DataFrame

issues_df
# Out:
#           Author   State   closed_at  created_at  issue_number  \
# 0    ZSP19SCM65P    open        None  2019-04-20           479
# 1    YSP19SCM26X  closed  2019-04-19  2019-04-18           477
# 2    RSP19SCM781    open        None  2019-04-18           476
# 3    RSP19SCM781    open        None  2019-04-18           475
# 4    TSP19SCM782    open        None  2019-04-18           474
# 5    TSP19SCM782    open        None  2019-04-18           473
# 6    TSP19SCM782    open        None  2019-04-18           472
# 7    DSP19SCM782    open        None  2019-04-18           471
# 8    DSP19SCM782    open        None  2019-04-18           470
# 9    TSP19SCM781    open        None  2019-04-18           469
# 10   TSP19SCM781    open        None  2019-04-18           468
# 11   TSP19SCM781    open        None  2019-04-18           467
# 12   YSP19SCM26X  closed  2019-04-18  2019-04-18           465
# 13   SSP19SCM782    open        None  2019-04-17           464
# 14   SSP19SCM782    open        None  2019-04-17           463
# 15   SSP19SCM781    open        None  2019-04-17           462
# 16   SSP19SCM781    open        None  2019-04-17           461
# 17   SSP19SCM781    open        None  2019-04-17           460
# 18   DSP19SCM782    open        None  2019-04-17           459
# 19   DSP19SCM782    open        None  2019-04-17           458
# 20   DSP19SCM782    open        None  2019-04-17           457
# 21   DSP19SCM781    open        None  2019-04-17           456
# 22   DSP19SCM781    open        None  2019-04-17           455
# 23   SSP19SCM782    open        None  2019-04-16           454
# 24   SSP19SCM782    open        None  2019-04-16           453
# 25   SSP19SCM781    open        None  2019-04-16           452
# 26   SSP19SCM781    open        None  2019-04-16           451
# 27   SSP19SCM781    open        None  2019-04-16           450
# 28   DSP19SCM782    open        None  2019-04-16           449
# 29   DSP19SCM782    open        None  2019-04-16           448
# ..           ...     ...         ...         ...           ...
# 315   SPM587SP19  closed  2019-04-03  2019-03-31            31
# 316   SPM587SP19  closed  2019-04-02  2019-03-31            30
# 317   SPM587SP19  closed  2019-04-07  2019-03-31            29
# 318   SPM587SP19  closed  2019-04-02  2019-03-31            28
# 319   SPM587SP19  closed  2019-04-03  2019-03-31            27
# 320   SPM587SP19  closed  2019-03-31  2019-03-31            26
# 321   SPM587SP19  closed  2019-03-31  2019-03-31            25
# 322   SPM587SP19  closed  2019-03-31  2019-03-31            24
# 323   SPM587SP19  closed  2019-03-31  2019-03-31            23
# 324   SPM587SP19  closed  2019-03-31  2019-03-31            22
# 325   SPM587SP19  closed  2019-03-31  2019-03-31            21
# 326   SPM587SP19  closed  2019-03-31  2019-03-31            20
# 327   SPM587SP19  closed  2019-03-31  2019-03-31            19
# 328   SPM587SP19  closed  2019-03-31  2019-03-31            18
# 329   SPM587SP19  closed  2019-03-31  2019-03-31            17
# 330   SPM587SP19  closed  2019-03-31  2019-03-31            16
# 331   SPM587SP19  closed  2019-03-31  2019-03-31            15
# 332   SPM587SP19  closed  2019-03-31  2019-03-31            14
# 333   SPM587SP19  closed  2019-03-31  2019-03-30            13
# 334   SPM587SP19  closed  2019-03-31  2019-03-30            12
# 335   SPM587SP19  closed  2019-03-31  2019-03-30            11
# 336   SPM587SP19  closed  2019-03-31  2019-03-30            10
# 337   SPM587SP19  closed  2019-03-31  2019-03-30             9
# 338   SPM587SP19  closed  2019-03-31  2019-03-30             8
# 339   SPM587SP19  closed  2019-03-31  2019-03-30             7
# 340   SPM587SP19  closed  2019-03-31  2019-03-30             6
# 341   SPM587SP19  closed  2019-03-31  2019-03-30             5
# 342   SPM587SP19  closed  2019-03-31  2019-03-29             4
# 343   SPM587SP19  closed  2019-03-31  2019-03-29             3
# 344   SPM587SP19  closed  2019-03-31  2019-03-24             1
#
#                                                 labels
# 0    [Address:McDonalds 2525 S King Dr Chicago 6061...
# 1    [Category:Inquiry, DetectionPhase:Field, Origi...
# 2    [Category:Bug, DetectionPhase:Field, Originati...
# 3    [Category:Inquiry, DetectionPhase:Design, Orig...
# 4    [Category:Enhancement, DetectionPhase:Design, ...
# 5    [Category:Bug, DetectionPhase:Design, Originat...
# 6    [Category:Enhancement, DetectionPhase:Testing,...
# 7    [Category:Inquiry, DetectionPhase:Design, Orig...
# 8    [Category:Bug, DetectionPhase:Testing, Origina...
# 9    [Category:Enhancement, DetectionPhase:Field, O...
# 10   [Category:Bug, DetectionPhase:Field, Originati...
# 11   [Category:Inquiry, DetectionPhase:Field, Oriti...
# 12   [Address:2525 S Martin Luther King Dr Chicago ...
# 13   [Category:Bug, DetectionPhase:Coding, Originat...
# 14   [Category:Inquiry, DetectionPhase:Testing, Ori...
# 15   [Category:Enhancement, DetectionPhase:Design, ...
# 16   [Category:Inquiry, DetectionPhase:Field, Origi...
# 17   [Category:Enhancement, DetectionPhase:Design, ...
# 18   [Category:Enhancement, DetectionPhase:Field, O...
# 19   [Category:Bug, DetectionPhase:Field, Originati...
# 20   [Category:Inquiry, DetectionPhase:Field, Oriti...
# 21   [Category:Inquiry, DetectionPhase:Field, Origi...
# 22   [Category:Inquiry, DetectionPhase:Field, Origi...
# 23   [Category:Enhancement, DetectionPhase:Design, ...
# 24   [Category:Bug, DetectionPhase:Testing, Origina...
# 25   [Category:Enhancement, DetectionPhase:Design, ...
# 26   [Category:Bug, DetectionPhase:Testing, Origina...
# 27   [Category:Enhancement, DetectionPhase:Design, ...
# 28   [Category:Enhancement, DetectionPhase:Field, O...
# 29   [Category:Inquiry, DetectionPhase:Field, Origi...
# ..                                                 ...
# 315  [Category:Bug, DetectionPhase:Design, Originat...
# 316  [Category:Inquiry, DetectionPhase:Coding, Orit...
# 317  [Category:Bug, DetectionPhase:Design, Originat...
# 318  [Category:Enhancement, DetectionPhase:Design, ...
# 319  [Category:Inquiry, DetectionPhase:Design, Orit...
# 320  [Category:Enhancement, DetectionPhase:Coding, ...
# 321  [Category:Inquiry, DetectionPhase:Design, Orig...
# 322  [Category:Enhancement, DetectionPhase:Coding, ...
# 323  [Category:Bug, DetectionPhase:Design, Originat...
# 324  [Category:Inquiry, DetectionPhase:Coding, Orig...
# 325  [Category:Bug, DetectionPhase:Design, Originat...
# 326  [Category:Bug, DetectionPhase:Coding, Oritinat...
# 327  [Category:Enhancement, DetectionPhase:Design, ...
# 328  [Category:Inquiry, DetectionPhase:Coding, Orig...
# 329  [Category:Bug, DetectionPhase:Field, Originati...
# 330  [Category:Inquiry, DetectionPhase:Design, Orig...
# 331  [Category:Enhancement, DetectionPhase:Coding, ...
# 332  [Category:Inquiry, DetectionPhase:Design, Orig...
# 333  [Category:Enhancement, DetectionPhase:Design, ...
# 334  [Category:Enhancement, DetectionPhase:Coding, ...
# 335  [Category:Enhancement, DetectionPhase:Design, ...
# 336  [Category:Bug, DetectionPhase:Coding, Originat...
# 337  [Category:Enhancement, DetectionPhase:Design, ...
# 338  [Category:Bug, DetectionPhase:Coding, Originat...
# 339  [Category:Inquiry, DetectionPhase:Design, Orig...
# 340  [Category:Inquiry, DetectionPhase:Field, Origi...
# 341  [Category:Inquiry, DetectionPhase:Field, Origi...
# 342  [Category:Inquiry, DetectionPhase:Field, Origi...
# 343  [Category:Inquiry, DetectionPhase:Field, Origi...
# 344  [Category:Inquiry, DetectionPhase:Field, Origi...
#
# [345 rows x 6 columns]

# %%
# Prepare and Clean the dataframe object

wrangled_issues_df = issues_df[['Author','State','closed_at','created_at','issue_number','labels']]
wrangled_issues_df.loc[0:len(wrangled_issues_df), 'OriginationPhase']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'DetectionPhase']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Category']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Priority']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Status']= np.NaN

# %%
wrangled_issues_df
# Out:
#           Author   State   closed_at  created_at  issue_number  \
# 0    ZSP19SCM65P    open        None  2019-04-20           479
# 1    YSP19SCM26X  closed  2019-04-19  2019-04-18           477
# 2    RSP19SCM781    open        None  2019-04-18           476
# 3    RSP19SCM781    open        None  2019-04-18           475
# 4    TSP19SCM782    open        None  2019-04-18           474
# 5    TSP19SCM782    open        None  2019-04-18           473
# 6    TSP19SCM782    open        None  2019-04-18           472
# 7    DSP19SCM782    open        None  2019-04-18           471
# 8    DSP19SCM782    open        None  2019-04-18           470
# 9    TSP19SCM781    open        None  2019-04-18           469
# 10   TSP19SCM781    open        None  2019-04-18           468
# 11   TSP19SCM781    open        None  2019-04-18           467
# 12   YSP19SCM26X  closed  2019-04-18  2019-04-18           465
# 13   SSP19SCM782    open        None  2019-04-17           464
# 14   SSP19SCM782    open        None  2019-04-17           463
# 15   SSP19SCM781    open        None  2019-04-17           462
# 16   SSP19SCM781    open        None  2019-04-17           461
# 17   SSP19SCM781    open        None  2019-04-17           460
# 18   DSP19SCM782    open        None  2019-04-17           459
# 19   DSP19SCM782    open        None  2019-04-17           458
# 20   DSP19SCM782    open        None  2019-04-17           457
# 21   DSP19SCM781    open        None  2019-04-17           456
# 22   DSP19SCM781    open        None  2019-04-17           455
# 23   SSP19SCM782    open        None  2019-04-16           454
# 24   SSP19SCM782    open        None  2019-04-16           453
# 25   SSP19SCM781    open        None  2019-04-16           452
# 26   SSP19SCM781    open        None  2019-04-16           451
# 27   SSP19SCM781    open        None  2019-04-16           450
# 28   DSP19SCM782    open        None  2019-04-16           449
# 29   DSP19SCM782    open        None  2019-04-16           448
# ..           ...     ...         ...         ...           ...
# 315   SPM587SP19  closed  2019-04-03  2019-03-31            31
# 316   SPM587SP19  closed  2019-04-02  2019-03-31            30
# 317   SPM587SP19  closed  2019-04-07  2019-03-31            29
# 318   SPM587SP19  closed  2019-04-02  2019-03-31            28
# 319   SPM587SP19  closed  2019-04-03  2019-03-31            27
# 320   SPM587SP19  closed  2019-03-31  2019-03-31            26
# 321   SPM587SP19  closed  2019-03-31  2019-03-31            25
# 322   SPM587SP19  closed  2019-03-31  2019-03-31            24
# 323   SPM587SP19  closed  2019-03-31  2019-03-31            23
# 324   SPM587SP19  closed  2019-03-31  2019-03-31            22
# 325   SPM587SP19  closed  2019-03-31  2019-03-31            21
# 326   SPM587SP19  closed  2019-03-31  2019-03-31            20
# 327   SPM587SP19  closed  2019-03-31  2019-03-31            19
# 328   SPM587SP19  closed  2019-03-31  2019-03-31            18
# 329   SPM587SP19  closed  2019-03-31  2019-03-31            17
# 330   SPM587SP19  closed  2019-03-31  2019-03-31            16
# 331   SPM587SP19  closed  2019-03-31  2019-03-31            15
# 332   SPM587SP19  closed  2019-03-31  2019-03-31            14
# 333   SPM587SP19  closed  2019-03-31  2019-03-30            13
# 334   SPM587SP19  closed  2019-03-31  2019-03-30            12
# 335   SPM587SP19  closed  2019-03-31  2019-03-30            11
# 336   SPM587SP19  closed  2019-03-31  2019-03-30            10
# 337   SPM587SP19  closed  2019-03-31  2019-03-30             9
# 338   SPM587SP19  closed  2019-03-31  2019-03-30             8
# 339   SPM587SP19  closed  2019-03-31  2019-03-30             7
# 340   SPM587SP19  closed  2019-03-31  2019-03-30             6
# 341   SPM587SP19  closed  2019-03-31  2019-03-30             5
# 342   SPM587SP19  closed  2019-03-31  2019-03-29             4
# 343   SPM587SP19  closed  2019-03-31  2019-03-29             3
# 344   SPM587SP19  closed  2019-03-31  2019-03-24             1
#
#                                                 labels  OriginationPhase  \
# 0    [Address:McDonalds 2525 S King Dr Chicago 6061...               NaN
# 1    [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 2    [Category:Bug, DetectionPhase:Field, Originati...               NaN
# 3    [Category:Inquiry, DetectionPhase:Design, Orig...               NaN
# 4    [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 5    [Category:Bug, DetectionPhase:Design, Originat...               NaN
# 6    [Category:Enhancement, DetectionPhase:Testing,...               NaN
# 7    [Category:Inquiry, DetectionPhase:Design, Orig...               NaN
# 8    [Category:Bug, DetectionPhase:Testing, Origina...               NaN
# 9    [Category:Enhancement, DetectionPhase:Field, O...               NaN
# 10   [Category:Bug, DetectionPhase:Field, Originati...               NaN
# 11   [Category:Inquiry, DetectionPhase:Field, Oriti...               NaN
# 12   [Address:2525 S Martin Luther King Dr Chicago ...               NaN
# 13   [Category:Bug, DetectionPhase:Coding, Originat...               NaN
# 14   [Category:Inquiry, DetectionPhase:Testing, Ori...               NaN
# 15   [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 16   [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 17   [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 18   [Category:Enhancement, DetectionPhase:Field, O...               NaN
# 19   [Category:Bug, DetectionPhase:Field, Originati...               NaN
# 20   [Category:Inquiry, DetectionPhase:Field, Oriti...               NaN
# 21   [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 22   [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 23   [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 24   [Category:Bug, DetectionPhase:Testing, Origina...               NaN
# 25   [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 26   [Category:Bug, DetectionPhase:Testing, Origina...               NaN
# 27   [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 28   [Category:Enhancement, DetectionPhase:Field, O...               NaN
# 29   [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# ..                                                 ...               ...
# 315  [Category:Bug, DetectionPhase:Design, Originat...               NaN
# 316  [Category:Inquiry, DetectionPhase:Coding, Orit...               NaN
# 317  [Category:Bug, DetectionPhase:Design, Originat...               NaN
# 318  [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 319  [Category:Inquiry, DetectionPhase:Design, Orit...               NaN
# 320  [Category:Enhancement, DetectionPhase:Coding, ...               NaN
# 321  [Category:Inquiry, DetectionPhase:Design, Orig...               NaN
# 322  [Category:Enhancement, DetectionPhase:Coding, ...               NaN
# 323  [Category:Bug, DetectionPhase:Design, Originat...               NaN
# 324  [Category:Inquiry, DetectionPhase:Coding, Orig...               NaN
# 325  [Category:Bug, DetectionPhase:Design, Originat...               NaN
# 326  [Category:Bug, DetectionPhase:Coding, Oritinat...               NaN
# 327  [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 328  [Category:Inquiry, DetectionPhase:Coding, Orig...               NaN
# 329  [Category:Bug, DetectionPhase:Field, Originati...               NaN
# 330  [Category:Inquiry, DetectionPhase:Design, Orig...               NaN
# 331  [Category:Enhancement, DetectionPhase:Coding, ...               NaN
# 332  [Category:Inquiry, DetectionPhase:Design, Orig...               NaN
# 333  [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 334  [Category:Enhancement, DetectionPhase:Coding, ...               NaN
# 335  [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 336  [Category:Bug, DetectionPhase:Coding, Originat...               NaN
# 337  [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 338  [Category:Bug, DetectionPhase:Coding, Originat...               NaN
# 339  [Category:Inquiry, DetectionPhase:Design, Orig...               NaN
# 340  [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 341  [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 342  [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 343  [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 344  [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
#
#      DetectionPhase  Category  Priority  Status
# 0               NaN       NaN       NaN     NaN
# 1               NaN       NaN       NaN     NaN
# 2               NaN       NaN       NaN     NaN
# 3               NaN       NaN       NaN     NaN
# 4               NaN       NaN       NaN     NaN
# 5               NaN       NaN       NaN     NaN
# 6               NaN       NaN       NaN     NaN
# 7               NaN       NaN       NaN     NaN
# 8               NaN       NaN       NaN     NaN
# 9               NaN       NaN       NaN     NaN
# 10              NaN       NaN       NaN     NaN
# 11              NaN       NaN       NaN     NaN
# 12              NaN       NaN       NaN     NaN
# 13              NaN       NaN       NaN     NaN
# 14              NaN       NaN       NaN     NaN
# 15              NaN       NaN       NaN     NaN
# 16              NaN       NaN       NaN     NaN
# 17              NaN       NaN       NaN     NaN
# 18              NaN       NaN       NaN     NaN
# 19              NaN       NaN       NaN     NaN
# 20              NaN       NaN       NaN     NaN
# 21              NaN       NaN       NaN     NaN
# 22              NaN       NaN       NaN     NaN
# 23              NaN       NaN       NaN     NaN
# 24              NaN       NaN       NaN     NaN
# 25              NaN       NaN       NaN     NaN
# 26              NaN       NaN       NaN     NaN
# 27              NaN       NaN       NaN     NaN
# 28              NaN       NaN       NaN     NaN
# 29              NaN       NaN       NaN     NaN
# ..              ...       ...       ...     ...
# 315             NaN       NaN       NaN     NaN
# 316             NaN       NaN       NaN     NaN
# 317             NaN       NaN       NaN     NaN
# 318             NaN       NaN       NaN     NaN
# 319             NaN       NaN       NaN     NaN
# 320             NaN       NaN       NaN     NaN
# 321             NaN       NaN       NaN     NaN
# 322             NaN       NaN       NaN     NaN
# 323             NaN       NaN       NaN     NaN
# 324             NaN       NaN       NaN     NaN
# 325             NaN       NaN       NaN     NaN
# 326             NaN       NaN       NaN     NaN
# 327             NaN       NaN       NaN     NaN
# 328             NaN       NaN       NaN     NaN
# 329             NaN       NaN       NaN     NaN
# 330             NaN       NaN       NaN     NaN
# 331             NaN       NaN       NaN     NaN
# 332             NaN       NaN       NaN     NaN
# 333             NaN       NaN       NaN     NaN
# 334             NaN       NaN       NaN     NaN
# 335             NaN       NaN       NaN     NaN
# 336             NaN       NaN       NaN     NaN
# 337             NaN       NaN       NaN     NaN
# 338             NaN       NaN       NaN     NaN
# 339             NaN       NaN       NaN     NaN
# 340             NaN       NaN       NaN     NaN
# 341             NaN       NaN       NaN     NaN
# 342             NaN       NaN       NaN     NaN
# 343             NaN       NaN       NaN     NaN
# 344             NaN       NaN       NaN     NaN
#
# [345 rows x 11 columns]

# %%
for i in range(0, len(wrangled_issues_df)):
   if wrangled_issues_df.iloc[i]['labels']:
        for label in wrangled_issues_df.iloc[i]['labels']:
            label_name= (label.split(':'))[0]
            label_value= (label.split(':'))[1]
            wrangled_issues_df.loc[i, label_name]=label_value

# %%
wrangled_issues_df
# Out:
#           Author   State   closed_at  created_at  issue_number  \
# 0    ZSP19SCM65P    open        None  2019-04-20           479
# 1    YSP19SCM26X  closed  2019-04-19  2019-04-18           477
# 2    RSP19SCM781    open        None  2019-04-18           476
# 3    RSP19SCM781    open        None  2019-04-18           475
# 4    TSP19SCM782    open        None  2019-04-18           474
# 5    TSP19SCM782    open        None  2019-04-18           473
# 6    TSP19SCM782    open        None  2019-04-18           472
# 7    DSP19SCM782    open        None  2019-04-18           471
# 8    DSP19SCM782    open        None  2019-04-18           470
# 9    TSP19SCM781    open        None  2019-04-18           469
# 10   TSP19SCM781    open        None  2019-04-18           468
# 11   TSP19SCM781    open        None  2019-04-18           467
# 12   YSP19SCM26X  closed  2019-04-18  2019-04-18           465
# 13   SSP19SCM782    open        None  2019-04-17           464
# 14   SSP19SCM782    open        None  2019-04-17           463
# 15   SSP19SCM781    open        None  2019-04-17           462
# 16   SSP19SCM781    open        None  2019-04-17           461
# 17   SSP19SCM781    open        None  2019-04-17           460
# 18   DSP19SCM782    open        None  2019-04-17           459
# 19   DSP19SCM782    open        None  2019-04-17           458
# 20   DSP19SCM782    open        None  2019-04-17           457
# 21   DSP19SCM781    open        None  2019-04-17           456
# 22   DSP19SCM781    open        None  2019-04-17           455
# 23   SSP19SCM782    open        None  2019-04-16           454
# 24   SSP19SCM782    open        None  2019-04-16           453
# 25   SSP19SCM781    open        None  2019-04-16           452
# 26   SSP19SCM781    open        None  2019-04-16           451
# 27   SSP19SCM781    open        None  2019-04-16           450
# 28   DSP19SCM782    open        None  2019-04-16           449
# 29   DSP19SCM782    open        None  2019-04-16           448
# ..           ...     ...         ...         ...           ...
# 315   SPM587SP19  closed  2019-04-03  2019-03-31            31
# 316   SPM587SP19  closed  2019-04-02  2019-03-31            30
# 317   SPM587SP19  closed  2019-04-07  2019-03-31            29
# 318   SPM587SP19  closed  2019-04-02  2019-03-31            28
# 319   SPM587SP19  closed  2019-04-03  2019-03-31            27
# 320   SPM587SP19  closed  2019-03-31  2019-03-31            26
# 321   SPM587SP19  closed  2019-03-31  2019-03-31            25
# 322   SPM587SP19  closed  2019-03-31  2019-03-31            24
# 323   SPM587SP19  closed  2019-03-31  2019-03-31            23
# 324   SPM587SP19  closed  2019-03-31  2019-03-31            22
# 325   SPM587SP19  closed  2019-03-31  2019-03-31            21
# 326   SPM587SP19  closed  2019-03-31  2019-03-31            20
# 327   SPM587SP19  closed  2019-03-31  2019-03-31            19
# 328   SPM587SP19  closed  2019-03-31  2019-03-31            18
# 329   SPM587SP19  closed  2019-03-31  2019-03-31            17
# 330   SPM587SP19  closed  2019-03-31  2019-03-31            16
# 331   SPM587SP19  closed  2019-03-31  2019-03-31            15
# 332   SPM587SP19  closed  2019-03-31  2019-03-31            14
# 333   SPM587SP19  closed  2019-03-31  2019-03-30            13
# 334   SPM587SP19  closed  2019-03-31  2019-03-30            12
# 335   SPM587SP19  closed  2019-03-31  2019-03-30            11
# 336   SPM587SP19  closed  2019-03-31  2019-03-30            10
# 337   SPM587SP19  closed  2019-03-31  2019-03-30             9
# 338   SPM587SP19  closed  2019-03-31  2019-03-30             8
# 339   SPM587SP19  closed  2019-03-31  2019-03-30             7
# 340   SPM587SP19  closed  2019-03-31  2019-03-30             6
# 341   SPM587SP19  closed  2019-03-31  2019-03-30             5
# 342   SPM587SP19  closed  2019-03-31  2019-03-29             4
# 343   SPM587SP19  closed  2019-03-31  2019-03-29             3
# 344   SPM587SP19  closed  2019-03-31  2019-03-24             1
#
#                                                 labels OriginationPhase  \
# 0    [Address:McDonalds 2525 S King Dr Chicago 6061...           Design
# 1    [Category:Inquiry, DetectionPhase:Field, Origi...          Testing
# 2    [Category:Bug, DetectionPhase:Field, Originati...    Documentation
# 3    [Category:Inquiry, DetectionPhase:Design, Orig...          Testing
# 4    [Category:Enhancement, DetectionPhase:Design, ...          Testing
# 5    [Category:Bug, DetectionPhase:Design, Originat...          Testing
# 6    [Category:Enhancement, DetectionPhase:Testing,...           Design
# 7    [Category:Inquiry, DetectionPhase:Design, Orig...     Requirements
# 8    [Category:Bug, DetectionPhase:Testing, Origina...           Coding
# 9    [Category:Enhancement, DetectionPhase:Field, O...            Field
# 10   [Category:Bug, DetectionPhase:Field, Originati...     Requirements
# 11   [Category:Inquiry, DetectionPhase:Field, Oriti...              NaN
# 12   [Address:2525 S Martin Luther King Dr Chicago ...     Requirements
# 13   [Category:Bug, DetectionPhase:Coding, Originat...          Testing
# 14   [Category:Inquiry, DetectionPhase:Testing, Ori...              NaN
# 15   [Category:Enhancement, DetectionPhase:Design, ...              NaN
# 16   [Category:Inquiry, DetectionPhase:Field, Origi...    Documentation
# 17   [Category:Enhancement, DetectionPhase:Design, ...     Requirements
# 18   [Category:Enhancement, DetectionPhase:Field, O...            Field
# 19   [Category:Bug, DetectionPhase:Field, Originati...    Documentation
# 20   [Category:Inquiry, DetectionPhase:Field, Oriti...              NaN
# 21   [Category:Inquiry, DetectionPhase:Field, Origi...          Testing
# 22   [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 23   [Category:Enhancement, DetectionPhase:Design, ...     Requirements
# 24   [Category:Bug, DetectionPhase:Testing, Origina...     Requirements
# 25   [Category:Enhancement, DetectionPhase:Design, ...              NaN
# 26   [Category:Bug, DetectionPhase:Testing, Origina...          Testing
# 27   [Category:Enhancement, DetectionPhase:Design, ...     Requirements
# 28   [Category:Enhancement, DetectionPhase:Field, O...    Documentation
# 29   [Category:Inquiry, DetectionPhase:Field, Origi...          Testing
# ..                                                 ...              ...
# 315  [Category:Bug, DetectionPhase:Design, Originat...     Requirements
# 316  [Category:Inquiry, DetectionPhase:Coding, Orit...              NaN
# 317  [Category:Bug, DetectionPhase:Design, Originat...    Documentation
# 318  [Category:Enhancement, DetectionPhase:Design, ...     Requirements
# 319  [Category:Inquiry, DetectionPhase:Design, Orit...              NaN
# 320  [Category:Enhancement, DetectionPhase:Coding, ...           Coding
# 321  [Category:Inquiry, DetectionPhase:Design, Orig...           Coding
# 322  [Category:Enhancement, DetectionPhase:Coding, ...    Documentation
# 323  [Category:Bug, DetectionPhase:Design, Originat...            Field
# 324  [Category:Inquiry, DetectionPhase:Coding, Orig...     Requirements
# 325  [Category:Bug, DetectionPhase:Design, Originat...          Testing
# 326  [Category:Bug, DetectionPhase:Coding, Oritinat...              NaN
# 327  [Category:Enhancement, DetectionPhase:Design, ...              NaN
# 328  [Category:Inquiry, DetectionPhase:Coding, Orig...          Testing
# 329  [Category:Bug, DetectionPhase:Field, Originati...     Requirements
# 330  [Category:Inquiry, DetectionPhase:Design, Orig...            Field
# 331  [Category:Enhancement, DetectionPhase:Coding, ...    Documentation
# 332  [Category:Inquiry, DetectionPhase:Design, Orig...           Coding
# 333  [Category:Enhancement, DetectionPhase:Design, ...              NaN
# 334  [Category:Enhancement, DetectionPhase:Coding, ...          Testing
# 335  [Category:Enhancement, DetectionPhase:Design, ...     Requirements
# 336  [Category:Bug, DetectionPhase:Coding, Originat...            Field
# 337  [Category:Enhancement, DetectionPhase:Design, ...    Documentation
# 338  [Category:Bug, DetectionPhase:Coding, Originat...           Coding
# 339  [Category:Inquiry, DetectionPhase:Design, Orig...           Coding
# 340  [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 341  [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 342  [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 343  [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 344  [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
#
#     DetectionPhase     Category  Priority         Status  \
# 0           Design          Bug    Medium       Approved
# 1            Field      Inquiry      High     inProgress
# 2            Field          Bug      High     inProgress
# 3           Design      Inquiry     Major     inProgress
# 4           Design  Enhancement    Medium       Rejected
# 5           Design          Bug     Major     inProgress
# 6          Testing  Enhancement       Low  pendingReview
# 7           Design      Inquiry     Major      Completed
# 8          Testing          Bug     Major      Completed
# 9            Field  Enhancement      High     inProgress
# 10           Field          Bug      High  pendingReview
# 11           Field      Inquiry  Critical       Rejected
# 12          Design          Bug  Critical       Approved
# 13          Coding          Bug     Major      Completed
# 14         Testing      Inquiry       Low  pendingReview
# 15          Design  Enhancement     Major       Approved
# 16           Field      Inquiry    Medium       Rejected
# 17          Design  Enhancement       Low  pendingReview
# 18           Field  Enhancement      High     inProgress
# 19           Field          Bug      High       Approved
# 20           Field      Inquiry  Critical     inProgress
# 21           Field      Inquiry  Critical      Completed
# 22           Field      Inquiry  Critical       Approved
# 23          Design  Enhancement    Medium       Rejected
# 24         Testing          Bug     Major       Rejected
# 25          Design  Enhancement     Major      Completed
# 26         Testing          Bug       Low       Rejected
# 27          Design  Enhancement     Major  pendingReview
# 28           Field  Enhancement      High     inProgress
# 29           Field      Inquiry      High       Approved
# ..             ...          ...       ...            ...
# 315         Design          Bug     Major  pendingReview
# 316         Coding      Inquiry      High     inProgress
# 317         Design          Bug    Medium      Completed
# 318         Design  Enhancement     Major  pendingReview
# 319         Design      Inquiry    Medium       Rejected
# 320         Coding  Enhancement     Major       Approved
# 321         Design      Inquiry       Low      Completed
# 322         Coding  Enhancement       Low     inProgress
# 323         Design          Bug      High       Rejected
# 324         Coding      Inquiry     Major  pendingReview
# 325         Design          Bug       Low      Completed
# 326         Coding          Bug     Major     inProgress
# 327         Design  Enhancement       Low       Approved
# 328         Coding      Inquiry    Medium       Rejected
# 329          Field          Bug    Medium  pendingReview
# 330         Design      Inquiry     Major      Completed
# 331         Coding  Enhancement       Low     inProgress
# 332         Design      Inquiry      High       Approved
# 333         Design  Enhancement     Major     inProgress
# 334         Coding  Enhancement       Low       Rejected
# 335         Design  Enhancement      High     inProgress
# 336         Coding          Bug     Major      Completed
# 337         Design  Enhancement     Major       Rejected
# 338         Coding          Bug      High     inProgress
# 339         Design      Inquiry       Low       Approved
# 340          Field      Inquiry       Low       Approved
# 341          Field      Inquiry       Low  pendingReview
# 342          Field      Inquiry    Medium  pendingReview
# 343          Field      Inquiry    Medium  pendingReview
# 344          Field      Inquiry    Medium  pendingReview
#
#                                         Address OritinationPhase   Latitude  \
# 0        McDonalds 2525 S King Dr Chicago 60616              NaN        NaN
# 1                                           NaN              NaN        NaN
# 2                                           NaN              NaN        NaN
# 3                                           NaN              NaN        NaN
# 4                                           NaN              NaN        NaN
# 5                                           NaN              NaN        NaN
# 6                                           NaN              NaN        NaN
# 7                                           NaN              NaN        NaN
# 8                                           NaN              NaN        NaN
# 9                                           NaN              NaN        NaN
# 10                                          NaN              NaN        NaN
# 11                                          NaN           Design        NaN
# 12   2525 S Martin Luther King Dr Chicago 60616              NaN  41.847200
# 13                                          NaN              NaN        NaN
# 14                                          NaN           Design        NaN
# 15                                          NaN           Design        NaN
# 16                                          NaN              NaN        NaN
# 17                                          NaN              NaN        NaN
# 18                                          NaN              NaN        NaN
# 19                                          NaN              NaN        NaN
# 20                                          NaN           Design        NaN
# 21                                          NaN              NaN        NaN
# 22                                          NaN              NaN        NaN
# 23                                          NaN              NaN        NaN
# 24                                          NaN              NaN        NaN
# 25                                          NaN           Design        NaN
# 26                                          NaN              NaN        NaN
# 27                                          NaN              NaN        NaN
# 28                                          NaN              NaN        NaN
# 29                                          NaN              NaN        NaN
# ..                                          ...              ...        ...
# 315                                         NaN              NaN        NaN
# 316                                         NaN           Design        NaN
# 317                                         NaN              NaN        NaN
# 318                                         NaN              NaN        NaN
# 319                                         NaN           Design        NaN
# 320                                         NaN              NaN        NaN
# 321                                         NaN              NaN        NaN
# 322                                         NaN              NaN        NaN
# 323                                         NaN              NaN        NaN
# 324                                         NaN              NaN        NaN
# 325                                         NaN              NaN        NaN
# 326                                         NaN           Design        NaN
# 327                                         NaN           Design        NaN
# 328                                         NaN              NaN        NaN
# 329                                         NaN              NaN        NaN
# 330                                         NaN              NaN        NaN
# 331                                         NaN              NaN        NaN
# 332                                         NaN              NaN        NaN
# 333                                         NaN           Design        NaN
# 334                                         NaN              NaN        NaN
# 335                                         NaN              NaN        NaN
# 336                                         NaN              NaN        NaN
# 337                                         NaN              NaN        NaN
# 338                                         NaN              NaN        NaN
# 339                                         NaN              NaN        NaN
# 340                                         NaN              NaN        NaN
# 341                                         NaN              NaN        NaN
# 342                                         NaN              NaN        NaN
# 343                                         NaN              NaN        NaN
# 344                                         NaN              NaN        NaN
#
#       Longitude Detection Origination
# 0           NaN       NaN         NaN
# 1           NaN       NaN         NaN
# 2           NaN       NaN         NaN
# 3           NaN       NaN         NaN
# 4           NaN       NaN         NaN
# 5           NaN       NaN         NaN
# 6           NaN       NaN         NaN
# 7           NaN       NaN         NaN
# 8           NaN       NaN         NaN
# 9           NaN       NaN         NaN
# 10          NaN       NaN         NaN
# 11          NaN       NaN         NaN
# 12   -87.617188       NaN         NaN
# 13          NaN       NaN         NaN
# 14          NaN       NaN         NaN
# 15          NaN       NaN         NaN
# 16          NaN       NaN         NaN
# 17          NaN       NaN         NaN
# 18          NaN       NaN         NaN
# 19          NaN       NaN         NaN
# 20          NaN       NaN         NaN
# 21          NaN       NaN         NaN
# 22          NaN       NaN         NaN
# 23          NaN       NaN         NaN
# 24          NaN       NaN         NaN
# 25          NaN       NaN         NaN
# 26          NaN       NaN         NaN
# 27          NaN       NaN         NaN
# 28          NaN       NaN         NaN
# 29          NaN       NaN         NaN
# ..          ...       ...         ...
# 315         NaN       NaN         NaN
# 316         NaN       NaN         NaN
# 317         NaN       NaN         NaN
# 318         NaN       NaN         NaN
# 319         NaN       NaN         NaN
# 320         NaN       NaN         NaN
# 321         NaN       NaN         NaN
# 322         NaN       NaN         NaN
# 323         NaN       NaN         NaN
# 324         NaN       NaN         NaN
# 325         NaN       NaN         NaN
# 326         NaN       NaN         NaN
# 327         NaN       NaN         NaN
# 328         NaN       NaN         NaN
# 329         NaN       NaN         NaN
# 330         NaN       NaN         NaN
# 331         NaN       NaN         NaN
# 332         NaN       NaN         NaN
# 333         NaN       NaN         NaN
# 334         NaN       NaN         NaN
# 335         NaN       NaN         NaN
# 336         NaN       NaN         NaN
# 337         NaN       NaN         NaN
# 338         NaN       NaN         NaN
# 339         NaN       NaN         NaN
# 340         NaN       NaN         NaN
# 341         NaN       NaN         NaN
# 342         NaN       NaN         NaN
# 343         NaN       NaN         NaN
# 344         NaN       NaN         NaN
#
# [345 rows x 17 columns]

# %%
# Plot in Bar Chart the total number of issues "closed" every day for every Detaction Phase

LabelsReviewedByDate = wrangled_issues_df.groupby(['closed_at','OriginationPhase']).closed_at.count()

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['red', 'yellow', 'blue', 'purple', 'green'], grid=False)

# %%
# Plot in Bar Chart the total number of issues created for every Phase based on thier priorites

LabelsReviewedByDate = wrangled_issues_df.groupby(['Status','OriginationPhase']).created_at.count()
dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue','yellow', 'purple', 'red', 'green'], grid=False)

LabelsReviewedByDate = wrangled_issues_df.groupby(['Status','DetectionPhase']).created_at.count()
dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue','yellow', 'purple', 'red', 'green'], grid=False)

# %%
# Plot in Bar Chart the total number of issues closed every day for every Category

LabelsReviewedByDate = wrangled_issues_df.groupby(['closed_at','Category']).closed_at.count()

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'purple', 'red', 'yellow', 'green'], grid=False)

# %%
a = wrangled_issues_df[(wrangled_issues_df['DetectionPhase']=='Field') & (wrangled_issues_df['Priority']=='Critical')]
LabelsReviewedByDate =a.groupby(['DetectionPhase','Priority']).created_at.count()
dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'purple', 'red', 'yellow', 'green'], grid=False)



b = wrangled_issues_df[(wrangled_issues_df['DetectionPhase']=='Field') & (wrangled_issues_df['Status']=='Completed')]
LabelsReviewedByDate =b.groupby(['DetectionPhase','Status']).created_at.count()
dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'purple', 'red', 'yellow', 'green'], grid=False)

c = wrangled_issues_df[(wrangled_issues_df['DetectionPhase']=='Field') & (wrangled_issues_df['Priority']=='Critical') & (wrangled_issues_df['Status']=='Approved')]
LabelsReviewedByDate =c.groupby(['DetectionPhase','Priority']).created_at.count()
dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'purple', 'red', 'yellow', 'green'], grid=False)

#wrangled_issues_df[(wrangled_issues_df['DetectionPhase']=='Field') & (wrangled_issues_df['Priority']=='Critical') | (wrangled_issues_df['Priority']=='High') & (wrangled_issues_df['Status']=='Approved') | (wrangled_issues_df['Status']=='inProgress')]
d = wrangled_issues_df[(wrangled_issues_df['DetectionPhase']=='Field') & ((wrangled_issues_df['Priority']=='Critical') | (wrangled_issues_df['Priority']=='High')) & ((wrangled_issues_df['Status']=='Approved') | (wrangled_issues_df['Status']=='inProgress'))]
LabelsReviewedByDate =d.groupby(['DetectionPhase','Priority','Status']).created_at.count()
dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'purple', 'red', 'yellow', 'green'], grid=False)

#plt.bar(x,height=0.8)
#plt.bar(x, height=0.5, width=0.8)
#x_axis = [a,b,c]
#y_axis = [2, 8, 10]
#plt.bar(a, y_axis)
#plt.bar(range(1,len(a)+1), a, tick_label=a)
#dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'purple', 'red'], grid=False)
